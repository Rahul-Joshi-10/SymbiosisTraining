# %%
# Function defination
def times(a,b):
    return (a*b)

new_add = times("abc",30)

# %%
# Scope

def add2(x):
    print(id(x))
    x=x
    print(id(x))

add2(12)
# Out:
# 132073402679888
# 132073402679888
