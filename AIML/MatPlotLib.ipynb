# %%
import numpy as np
import matplotlib as mpl
from matplotlib.gridspec import GridSpec
import matplotlib.pyplot as plt

# %%
x1 = np.linspace(0, 2*np.pi, 100)
y1 = np.cos(x1)

plt.plot(X, Y, color='red') # plot will give Line
plt.scatter(X, Y, color='red')
plt.show() # scatter will give dots
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-875a90cf6172> in <cell line: 4>()
#       2 y1 = np.cos(x1)
#       3
# ----> 4 plt.plot(X, Y, color='red') # plot will give Line
#       5 plt.scatter(X, Y, color='red')
#       6 plt.show() # scatter will give dots
#
# NameError: name 'X' is not defined

# %%
# To save pdf as name figure.pdf in current folder
fig.savefig("figure.pdf")
plt.show()

# %%
x = np.linspace(0, 2*np.pi, 100)
y = np.cos(x)
fig , x = plt.subplots(1,3)   #  ROWs * column

# %%
G = plt.GridSpec(2,3)
ax = G[0,:]

# %%
import pandas as pd
df = pd.read_csv("/content/sample_data/california_housing_train.csv")
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
x1 = df['population'].values
y1 = df['median_income'].values

# %%
# First Scatter plot
plt.scatter(x1, y1, c ="r",linewidths = 2, marker ="D", edgecolor ="b", s = 70, alpha=0.5)

#Second Scatter plot
plt.plot(x1, y1, color="black")
plt.title('Multiple Scatter plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

x1 = df['total_rooms'].values
y1 = df['median_income'].values

model  = LinearRegression()
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.3)

# %%
model.fit(x_train.reshape(-1,1),y_train)

# %%
y_predict = model.predict(y_test.reshape(-1,1))

# %%
# First Scatter plot
plt.scatter(x_train, y_train, c ="r",linewidths = 2, marker ="D", edgecolor ="b", s = 70, alpha=0.5)

#Second Scatter plot
plt.plot(x_test, y_predict, color="black")
plt.title('Multiple Scatter plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

# %%
model.coef_

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

df = pd.read_csv("/content/Samples/insurance.csv")
df.head()
df['smoker'] = df['smoker'].replace({"yes":0,"no":1})
df
# Out:
#       age     sex     bmi  children  smoker     region      charges
# 0      19  female  27.900         0       0  southwest  16884.92400
# 1      18    male  33.770         1       1  southeast   1725.55230
# 2      28    male  33.000         3       1  southeast   4449.46200
# 3      33    male  22.705         0       1  northwest  21984.47061
# 4      32    male  28.880         0       1  northwest   3866.85520
# ...   ...     ...     ...       ...     ...        ...          ...
# 1333   50    male  30.970         3       1  northwest  10600.54830
# 1334   18  female  31.920         0       1  northeast   2205.98080
# 1335   18  female  36.850         0       1  southeast   1629.83350
# 1336   21  female  25.800         0       1  southwest   2007.94500
# 1337   61  female  29.070         0       0  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
x=df[["age"]]
y=df['smoker']

x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.3,random_state=5)

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
# Out:
# Text(0, 0.5, 'y-axis')

# %%
plt.plot('fake data index')
plt.xlabel("data")
plt.ylabel('Index')

plt.grid(True)
plt.figtext(0.995, 0.01, 'Footnote' , ha='right', va='bottom')
plt.legend(loc='best', framealpha=0.5,prop={'size':'small'})
plt.tight_layout(pad=1)
plt.gcf().set_size_inches(8,4)


y_predict = model.predict(x_test)
plt.scatter(x_test, y_test, c ="r",linewidths = 2, marker ="D", edgecolor ="b", s = 70, alpha=0.5)

#Second Scatter plot
plt.plot(x_test, y_predict, color="black")
plt.title('Multiple Scatter plot')

plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig = plt.figure()
for i in plt.get_fignums():
 fig = plt.figure(i) # get the figure
 print (fig.number)
 plt.close(fig.number) # close figure


ax = fig.add_subplot(2,2,1) # row-col-num
ax = fig.add_axes([0.1,0.1,0.8,0.8])
# Out:
# 1

# %%
fig, ax = plt.subplots()
fig,(ax1,ax2,ax3) = plt.subplots(nrows=3,
 ncols=1, sharex=True, figsize=(8,4))
fig.delaxes(ax2)
plt.show()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.3,random_state=5)

df.shape
# Out:
# (1338, 7)

# %%
N = 1338
size = 1338
colours = np.random.rand(N)
fig, ax = plt.subplots(figsize=(8,4))
l = ax.scatter(x, y, s=size, c=colours)
fig.colorbar(l)
ax.set_xlim((-0.05, 1.05))
ax.set_ylim((-0.05, 1.05))
fig.suptitle('Dramatic Scatter Plot')
fig.tight_layout(pad=2);
ax.grid(True)
fig.savefig('filename.png', dpi=125)

# %%
fig, ax = plt.subplots(figsize=(8,5))
markers = list('ov^<>12348sphHdD+x*|_')
N = 10
for i, m in enumerate(markers):
 x = np.arange(N)
 y = np.repeat(i+1, N)
 ax.scatter(x, y, marker=m, label=m,
 s=50, c='cornflowerblue')
ax.set_xlim((-1,N))
ax.set_ylim((0,len(markers)+1))
ax.legend(loc='upper left', ncol=5,
 prop={'size':'xx-large'},
 shadow=True, title='Marker Legend')

# alreday made legened is changed by get_legend
ax.get_legend().get_title().set_color("red")
fig.suptitle('Markers ' +
 '(with an oversized legend)')
fig.tight_layout(pad=2);
fig.savefig('filename.png', dpi=125)

# %%
df = pd.read_csv("https://gist.githubusercontent.com/noamross/e5d3e859aa0c794be10b/raw/b999fb4425b54c63cab088c0ce2c0d6ce961a563/cars.csv")
print(df.columns)
print(df)
df.gear.unique()
df = df.groupby('gear').max()
df2 = df.groupby('gear').min()
# Out:
# Index(['Unnamed: 0', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs',
#        'am', 'gear', 'carb'],
#       dtype='object')
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# ...

# %%
# --- get the data



N = 3
labels = df['cyl'][:N]
data = df['wt']
print(data)
# --- plot the data
fig, ax = plt.subplots(figsize=(8, 5))
width = 0.2;
tickLocations = np.arange(N)
rectLocations = tickLocations
ax.bar(rectLocations, data, width, color='gold', edgecolor='#000', linewidth=2.0)
# --- pretty-up the plot
ax.set_xticks(ticks= tickLocations)
ax.set_xticklabels(labels)
ax.set_yticks(data)
ax.yaxis.grid(True)
# --- title and save
fig.suptitle("Bar Plot with " +
 "Oversized Edges")
fig.tight_layout(pad=2)
fig.savefig('filename.png', dpi=125)
# Out:
# gear
# 3    5.424
# 4    3.440
# 5    3.570
# Name: wt, dtype: float64

# %%
alphas = df['wt']
betas = df2['wt']
labels =  df['cyl'][:N]
# --- the plot
fig, ax = plt.subplots(figsize=(8, 3.5))
width = 0.8;
xlocations=np.array(range(len(alphas)+2))
adjlocs = xlocations[1:-1]
ax.bar(adjlocs, betas, width,
 label='max', color='gold',
 bottom=alphas)
ax.bar(adjlocs, alphas, width,
 label='mix', color='skyblue')
# --- pretty-up and save
ax.set_xticks(ticks=xlocations[1:-1])
ax.set_xticklabels(labels)
ax.yaxis.grid(True)
ax.legend(loc='best', prop={'size':'small'})
fig.suptitle("Stacked Nonsense")
fig.tight_layout(pad=2)
fig.savefig('filename.png', dpi=125)

# %% [markdown]
# draw fig with 3 sub plot containing bar graph of verity
# 1 mean
# 2 count
# 3 maximum
