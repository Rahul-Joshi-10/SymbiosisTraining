# %%
# Recusion - function calling itself is called as recursion
# adv - Optimaization, simple to code
# Dis - Difficult to debugg

import math
print(math.floor(3.7))
print(math.ceil(3.7))
print(4//4)
# Out:
# 3
# 4
# 1

# %%
# Complex number
(1+3j )* 3
# Out:
# (3+9j)

# %%
print(0o23,     # (0o)-> zero and O for  Octal 8^0+8^1+8^2+......
0xff,           # (0x)-> Hex 16^0+16^1+16^2+.....
0b111,          # (0b)-> binary 1,10,11,100,101,110,111.......
oct(23),
hex(64),
bin(64),
oct(122),
int(0o100)
)
# Out:
# 19 255 7 0o27 0x40 0b1000000 0o172 64

# %%
print(int('100',8))
eval('0o100')
# Out:
# 64
# 64

# %%
# Convert inregers to octal and hex using string formating method
'{0:o},{1:x},{2:b}'.format(0x64,64,64)
'%o,%x,%X' % (64,64,64)
# Out:
# '100,40,40'

# %%
x=4
x<<2
# Out:
# 16

# %%
n=8
if n & (n-1):
    print(False)
else:
    print(True)
# Out:
# True

# %%
def pow(x, n):
    result=1
    if(n%2==0):
        for i in range(int(n/2)):
            result=result*x
        return result*result
    else:
        for i in range(int(n/2)):
            result=result*x
            # print(result)
        return (result*result)*x

pow(2,5)
# Out:
# 32

# %%
def pow1(x,n):
    result=1
    while n>0:
        if(n%2==1):
            result = result*x
        x = x*x
        n=n//2
    return result

print(pow1(2,5))
# Out:
# 32

# %%
def powRec(x,n):
    if(n==0):return 1
    if(n==1):return x
    if(n%2==1):
        return powRec(x,n-1)*x

    else:
        return powRec(x,n/2)**2

powRec(2,5)
# Out:
# 32

# %%
dictt = {item*3 for item in set('abc')}
dictt
# Out:
# {'aaa', 'bbb', 'ccc'}

# %%
var = [item for item in dict({'a':1,'b':2,'c':4})]

# %%
var = [item for item in list(['a','b','c'])]
var
# Out:
# ['a', 'b', 'c']

# %%
# ocatal to hex
def fun(octal):
    octal=str(octal)
    return int(octal,8)

# fun(0o190)

# %%
# Dynamic typing
# variables are created when we assigne them fist values

# %%
# DIffreence betn var ref and obj
# variables are entries in system table with spaces for link to objects
# object are pices of allocated memory with enough space to represent values for which they stand
# reference are automaticully followed pointers form variables to objects

# %%
a=33456
b=33456
print(id(b))
id(a)
# Out:
# 137340252693904
# 137340252693712

# %%
from multipledispatch import dispatch
class Shape:
    def __init__(self,redius=0,length=0,breath=0):
        self.r = redius
        self.l = length
        self.b = breath

    @dispatch(int,int,int)
    def area(self,r,l,b):
        if(self.r==0):
            return self.l*self.b
        else:
            return(math.pi*(self.r**2))

    @dispatch(int,int)
    def circum(self,r):
        if(self.r!=0):
            return(2*math.pi*self.r)

    @dispatch(int,int)
    def perimeter(self):
        return 2*(self.b+self.b)
# Out:
# 530.929158456675
# 81.68140899333463

# %%
from multipledispatch import dispatch

# passing one parameter

@dispatch(int, int)
def product(first, second):
    result = first*second
    print(result)

# passing two parameters


@dispatch(int, int, int)
def product(first, second, third):
    result = first * second * third
    print(result)

# you can also pass data type of any value as per requirement


@dispatch(float, float, float)
def product(first, second, third):
    result = first * second * third
    print(result)


# calling product method with 2 arguments
product(2, 3)  # this will give output of 6

# calling product method with 3 arguments but all int
product(2, 3, 2)  # this will give output of 12

# calling product method with 3 arguments but all float
product(2.2, 3.4, 2.3)
# Out:
# 6
# 12
# 17.204

# %%
# encoding
s = u'\spam'
type(s)
# Out:
# str

# %%
string = 'rahuljoshi201832'
string.find('8')
string.replace('20183','isgood')
string.split('i')
string.lower()
string.upper()
string.endswith('1832')
"joshi" in string
# Out:
# True
