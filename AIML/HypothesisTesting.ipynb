# %% [markdown]
# ![Screenshot 2024-07-15 085132.png](data:image/png;base64,...)![Screenshot 2024-07-15 085142.png](data:image/png;base64,...)

# %% [markdown]
# * The acceptance of H1 when H0 is true is called a Type I ERROR
# * The Probability of committing a type II error is called level of significance and it's denoted by α
#
# * Why did we choose a critical value of 10 for this example?
# Because this is a Bernoulli process, the expected number of
# defectives in a sample is np. So, if p = 0.05 we should expect
# 100 × 0.05 = 5 defectives in a sample of 100 chips. Therefore,
# 10 defectives would be strong evidence that p > 0.05.
# The problem of how to find a critical value for a desired level
# of significance of the hypothesis test will be studied later.
#
# * ![Screenshot 2024-07-15 090340.png](data:image/png;base64,...)
#
# * If X is a binomial random variable with n trials and probability
# of success of each trial p, then the limiting form of the
# distribution of Z = X − np / sqrt(np(1 − p)) where n → ∞ is the standard normal distribution

# %% [markdown]
# ![Screenshot 2024-07-15 092006.png](data:image/png;base64,...)![Screenshot 2024-07-15 092014.png](data:image/png;base64,...)

# %% [markdown]
# 1. α and β are related; decreasing one generally increases
# the other.
# 2. α can be set to a desired value by adjusting the critical
# value. Typically, α is set at 0.05 or 0.01.
# 3. Increasing n decreases both α and β.
# 4. β decreases as the distance between the true value and
# hypothesized value (H1) increases.

# %% [markdown]
# In our examples so far we have considered:
# *  H0: θ = θ0
# *  H1: θ > θ0.
#
# This is a one-tailed test with the critical region in the right-tail
# of the test statistic X.
#
# ![Screenshot 2024-07-15 092715.png](data:image/png;base64,...)
#
# Another one-tailed test could have the form,
# * H0: θ = θ0
# * H1: θ < θ0,
#
# in which the critical region is in the left-tail.

# %% [markdown]
# In a two-tailed test check for differences:
# * H0: θ = θ0
# * H1: θ != θ0,
#
# ![Screenshot 2024-07-15 093027.png](data:image/png;base64,...)

# %% [markdown]
# Question and Examples
# Consider a production line of resistors that are supposed to be
# 100 Ohms. Assume σ = 8. So, the hypotheses are:
# • H0: µ = 100
# • H1: µ 6= 100,
# Let X¯ be the sample mean for a sample of size n = 100.
# ![Screenshot 2024-07-15 093636.png](data:image/png;base64,...)
# ![Screenshot 2024-07-15 093719.png](data:image/png;base64,...)

# %% [markdown]
# ![z-test-formula.png](data:image/png;base64,...)![Screenshot 2024-07-15 094143.png](data:image/png;base64,...)
# ![Screenshot 2024-07-15 094740.png](data:image/png;base64,...)

# %% [markdown]
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTgPPuSGOvUUTmz6zpGzS0FsrssPRyo6kuGTFndPl8DlVs9w3bRWiBJCX2JsoYIx87MoJo&usqp=CAU" width=50%></img>

# %%
# Coding part

import numpy as np
from scipy import stats

students_socre =  np.array([72, 89, 65, 73, 79, 84, 63, 76, 85, 75])

# Hypothesized population mean
μ = 70

#  perfrom one-simple t-test
t_stat, p_value = stats.ttest_1samp(students_socre, μ )
print("T statistic : ",t_stat)
print("P_value : ",p_value)

# setting value of significance level
alpha = 0.05    

if p_value < alpha:
    print("Reject the null hypothesis; there is a significant difference between the sample mean and the hypothesized population mean.")
else:
    print("Fail to reject the null hypothesis; there is no significant difference between the sample mean and the hypothesized population mean.")
# Out:
# T statistic :  2.2894683580127317
# P_value :  0.047816221110566944
# Reject the null hypothesis; there is a significant difference between the sample mean and the hypothesized population mean.

# %%
# 2 Tail-test 
import seaborn as sns
import math

iris = sns.load_dataset('iris')

# store dataset into two species we want to compare
setosa = iris[iris.species=='setosa']
versicolor = iris[iris.species=='versicolor']

setosa_petal_lengths = setosa.petal_length
versicolor_petal_lengths = versicolor.petal_length

t_stat, p_value = stats.ttest_ind(setosa_petal_lengths, versicolor_petal_lengths)

alpha = 0.05


print((p_value))
if p_value < alpha:
    print("Reject the null hypothesis; there is a significant difference between the sample mean and the hypothesized population mean.")
else:
    print("Fail to reject the null hypothesis; there is no significant difference between the sample mean and the hypothesized population mean.")
# Out:
# 5.404910513441677e-62
# Reject the null hypothesis; there is a significant difference between the sample mean and the hypothesized population mean.

# %%
# 2 Tail-test 
import seaborn as sns
import math
# from decimal import Decimal,getcontext

# getcontext().prec = 3

iris = sns.load_dataset('iris')

# store dataset into two species we want to compare
setosa = iris[iris.species=='setosa']
versicolor = iris[iris.species=='versicolor']

setosa_petal_width = setosa.petal_width
versicolor_petal_width = versicolor.petal_width

t_stat, p_value = stats.ttest_ind(setosa_petal_width, versicolor_petal_width)

alpha = 0.05


print((p_value))
if p_value < alpha:
    print("Reject the null hypothesis; there is a significant difference between the sample mean and the hypothesized population mean.")
else:
    print("Fail to reject the null hypothesis; there is no significant difference between the sample mean and the hypothesized population mean.")
# Out:
# 3.831095388248162e-56
# Reject the null hypothesis; there is a significant difference between the sample mean and the hypothesized population mean.
