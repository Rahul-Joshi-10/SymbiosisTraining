# %% [markdown]
# Problem Statement – An automobile company manufactures both a two wheeler (TW) and a four wheeler (FW). A company manager wants to make the production of both types of vehicle according to the given data below:
#
# 1st data, Total number of vehicle (two-wheeler + four-wheeler)=v
# 2nd data, Total number of wheels = W
# The task is to find how many two-wheelers as well as four-wheelers need to manufacture as per the given data.
# Example :
#
# Input :
# 200  -> Value of V
# 540   -> Value of W
#
# Output :
# TW =130 FW=70
#
# Explanation:
# 130+70 = 200 vehicles
# (70*4)+(130*2)= 540 wheels
#
# Constraints :
#
# 2<=W
# W%2=0
# V<W
#
# x = no of 2 wheels
# y = no of 4 wheels
# #### x+y=v
# #### x = v-y
# #### 2x+4y=w
# #### 2(v-y)+4y=w

# %%
v= int(input("enter the no of v: "))
w= int(input("enter the no of w: "))
if v<w and w%2==0 and 2<=w and w>=2*v:
    y=(w-v*2)//2
    x = v-y

    print(f"{x} no's of 2 wheels")
    print(f"{y} no's of 4 wheels")
else:
    print("invalid")
# Out:
# invalid

# %% [markdown]
# given string find length of longest substring without repeating chatacters

# %%
def fun(str,current,i):
    if(i==len(str)):
        if(len(current)==len(str)):
            print(current)
        return
    fun(str,current,i+1)
    fun(str,current+str[i],i+1)

fun("ABCD","",0)
# Out:
# ABCD

# %%
str="AABBCCD"
dict1 = {}
start, end =0,0
for i in range(len(str)):
    if str[end] in dict1:
        start = max(dict1[str[end]])

# %% [markdown]
# find out longest palindrome substring from given substring

# %%
def pal(str,start=0,end=(len(str)-1)):
    if(start<=end):
        return True
    if(str[start]==str[end]):
        return  pal(str,start+1,end-1)
    else:
        return False

list1 = []
def subPal(str):
    maxlen = 0
    for i in range(len(str)):
        temp = ""
        for j in range(i,len(str)):
            temp = str[i:i-j+1]
            if(pal(temp)):
                list1.append(temp)
                maxlen = max(maxlen,len(temp))
    return maxlen
print(subPal("abaabaa"))
print(list1)
# Out:
# 6
# ['a', '', 'abaaba', 'abaab', 'abaa', 'aba', 'ab', '', '', 'baaba', 'baab', 'baa', 'ba', '', '', 'aaba', 'aab', 'aa', '', '', 'aba', 'ab', '', '', 'ba', '', '', '']

# %%
# map function working
s1="abcd"
s2 = "xyz1234"
# list2 = list(map(None, s1,s2))
# print(list2[0])

# %%
keys = ['rahul','ajinkya','kunal']
values = [1,5,8]
# converting zip to list
dict1 = list(zip(keys,values))
print(dict1)
# converting zip to dict
dict1 = dict(zip(keys,values))
print(dict1)

# for key in dict1.keys()   this will iterate only in keys
# Out:
# [('rahul', 1), ('ajinkya', 5), ('kunal', 8)]
# {'rahul': 1, 'ajinkya': 5, 'kunal': 8}

# %% [markdown]
# Armstrong Number

# %%
def armstrong(n):
    final = n
    num = n**3
    result = 0
    while(num>0):
        dig = num%10
        result = result+dig
        num=num//10
    return final==result
armstrong(13)
# Out:
# False

# %%
def rev(str):
    temp = list(str)
    start = 0
    end = len(str)-1
    while start<=end:
        temp[end],temp[start] = str[start],str[end]
        start = start+1
        end = end-1
    return temp

def revSentense(str):
    str = str.split(" ")
    temp = list(str)
    end = len(str)
    for i in str:
        temp[end] = rev(i)
        end=end-1
    return temp

print(rev("My name is Rahul"))
# Out:
# ['l', 'u', 'h', 'a', 'R', ' ', 's', 'i', ' ', 'e', 'm', 'a', 'n', ' ', 'y', 'M']

# %% [markdown]
# write user define function to print last name of student

# %%
dict1 ={}
def fun(str):
    fname=""
    lname=""
    for i in range(len(str)-1):
        if(str[i]!=" "):
            fname+=str[i]
        else:
            for j in range(i,len(str)):
                lname+=str[j]
            break
    dict1[fname] = lname
    return dict1


string=input("Enter your frist name and last name")
print(fun(string))
# Out:
# {'1531': ''}

# %%
dict2 = {}
id = 0
def fun2(str):
    for i in str:
        if(i!=" "):
            id = id+1
    dict1[str[:id]] = dict1[str[id:]]
    return dict1

fun2("rahul joshi")
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[10], line 10
#       7     dict1[str[:id]] = dict1[str[id:]]
#       8     return dict1
# ---> 10 fun2("rahul joshi")
#
# Cell In[10], line 6, in fun2(str)
#       4 for i in str:
#       5     if(i!=" "):
# ----> 6         id = id+1
#       7 dict1[str[:id]] = dict1[str[id:]]
#       8 return dict1
#
# UnboundLocalError: cannot access local variable 'id' where it is not associated with a value

# %% [markdown]
# write a program to remove space from start and any extra space in between

# %%
def fun3(str):
    temp = ""
    start = 0
    while start==len(str)-1:
        if str[start]==" ":
            if str[start]==str[start+1]:
                temp+=str[start]
                break
        else:
            temp+=str[start]
            start+=1
    print(temp)
fun3("  rahul Joshi ")

# %% [markdown]
# add ing to end of string
# if string is ending with D or N

# %%
def addIng(str):
    temp=""
    last = len(str)-1
    if str[last]=='d' or str[last]=='n'or str[last]=='D'or str[last]=='N':
        temp=temp+str+"ing"
    return temp
addIng("NON")
# Out:
# 'NONing'

# %% [markdown]
# write a program if string is ending 'sion' 'ship' to end

# %%
def addShip(str):
    temp = ""
    last = str[len(str)-4:]
    if last=='sion':
        temp= temp+str+"ship"
    return temp

addShip("rasion")
# Out:
# 'rasionship'

# %%
def  printEven(str):
    even=""
    odd = ""
    cnt1=0
    cnt2=0
    for i in range(len(str)-1):
        if(i%2==0):
            even+=str[i]
            cnt1+=1
        else:
            odd+=str[i]
            cnt2+=1
    print(even,cnt1)
    print(odd,cnt2)

printEven("rahuljoshi")
# Out:
# rhloh
# aujs

# %% [markdown]
# Replace First char of each words with upper

# %%
def isCaptital(str1):
    first=str1[0]
    if ord(first) > 97 or ord(first)<122:
        cap=chr(ord(first)-32)
        temp =""
        temp =temp+cap+str1[1:]
        print(temp)
isCaptital("rahul")
# Out:
# Rahul

# %% [markdown]
# ## Dynamic Programing
# * Steps to solve dynamic programing
#
#
# 1.   Recognize Dynamic problem
# 2.   Identify Problem Variables
# 3.   Express The recurrence Relation
# 4.   Identify the Base case
# 5.   Decide the iterative or Recursive Approch
# 6.   Add memorization
#
# * Characterstics Of DP problems
#
# ![Screenshot 2024-07-11 123621.png](data:image/png;base64,...)

# %%
# Out:
# [[None, None, None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, None, None, None, None, None, None, None]]

# %%
# write a program to move all zeros at end of string while maintaining the order of elements in array

str="00123"
def fun(str):
    first=""
    last =""
    temp=""
    for i in str:
        if i=="0":
            last+=i
        else:
            first+=i
    temp = temp+first+last
    print(temp)
fun(str)
# Out:
# 12300

# %%
def fun(arr):
    j = len(arr)
    for i in arr:
        if i==0:
            for j in range(i,len(arr)-1):
                arr[j-1] = arr[j]
            arr[len(arr)]arr[i]

# %%
# Write a program to replace all the vowels  replace with capitals

def isCaptital(str1):
    cap=""
    if ord(str1) > 97 or ord(str1)<122:
        cap+=chr(ord(str1)-32)
    return cap

def fun(str):
    temp=""
    for i in str:
        if i=='a' or i=='e' or i=='o' or i=='u':
            temp += isCaptital(i)
        else:
            temp+=i
    return temp
fun("rahul")

dict1={'a':"A",
       'e':"E",
       'i':"I",
       'o':"O",}
def fun3(str):
    for i in str:
        if i in dict1:
            j=str.index(i)
            str = str[:j] + isCaptital(i) +str[j+1:]
    return str

fun3("rahul")
# Out:
# 'rAhul'

# %%
# write a program to write maximun of sumetion from sub list in contigious fasion
list1 = [2,5,6,7,8]
k=0

def fun(arr,n):
    result = 0
    for i in range(len(arr)-n+1):
        maxi = 0
        for j in range(i,i+n):
            maxi+=arr[j]
        result = max(result,maxi)
    return result

fun(list1,2)
# Out:
# 15

# %% [markdown]
# #### Recursion
# * Base case: Termination condition
# * Recursive case: more case are required to solve problem

# %%
def fun4(num):
    if num==0:
        return 1
    return num*fun4(num-1)
def fun5(num):
    result = 1
    for i in range(1,num+1):
        result = result*i
    return result



fun5(4)
# Out:
# 24

# %%
def sumlist(items):
    if items ==[]:
        return 0
# item[0] this will return 1st item and [1:] this will return list excluding first item
    return items[0]+sumlist(items[1:])
sumlist([1,9,8])
# Out:
# 18

# %%
def fun(list1,list2,i,j):
    if j < 0:
        return 0
    list2[j] = list1[i]
    return fun(list1,list2,i+1,j-1)

list1 =[1,2,3,4,5]
list2 = list(range(len(list1)))

fun(list1,list2,0,len(list1)-1)
print(list2)
# Out:
# [5, 4, 3, 2, 1]

# %%
def fibo(num):
    if num==0:
        return 0
    if num==1:
        return 1
    return fibo(num-1)+fibo(num-2)

def fiboo(list1,size):
    if size == 0:
        list1[0]=0
        return
    list1[size] = fibo(size)
    return fiboo(list1,size-1)

fiboo(list1,4)
print(list1)
# Out:
# [0, 1, 1, 2, 3]

# %%
def fun(str,start,end):
    if(start>=end):
        return True
    return(str[start]==str[end]) and fun(str,start+1,end-1)

str="abbaa"
end = len(str)-1
fun(str,0,end)
# Out:
# False

# %%
# write a program which print sum of digits of num

def fun(num):
    if num==0:
        return 0
    dig= num%10
    return dig+(fun(num//10))

fun(123)
# Out:
# 6

# %%
# find min of list using recursion
min=0
def fun(list1,start,end,result):
    if start>=end:
         return result
    if list1[start]>=list1[end]:
        result = list1[end]
        fun(list1,start+1,end,result)
    else:
        result = list1[start]
        fun(list1,start,end-1,result)

list1=[35,42,5,6,1,34,6]

fun(list1,0,len(list1)-1,0)

# %%
# Write a program
def fun9(arr):
    if len(arr)==1:
        return arr[0]
    return min(arr[:1],fun9(arr[1:]))
var =[12,45,3,21,5,67]
fun9(list(var))

# %%
def GCD(a,b):
    if b==0:
        return a
    return GCD(b,a%b)

GCD(18,21)
# Out:
# 3

# %%
def fun(a,b):

    if a==0:
        return b
    if b==0:
        return a
    if a==b:
        return a
    if a>b:
        return fun(a-b,b)
    else:
        return(a,b-a)

# %%
def GCD(a,b):
    if b==0:
        return a
    return GCD(b,a%b)


def LCM(a,b):
    return a*b//GCD(a,b)

LCM(5,7)
# Out:
# 35

# %%
# inputt = input("Enter the expr:")
# 3+(2*(4+8))/6
def value(str):
    if str=='*': return 3
    if str=='/': return 2
    if str=='+': return 1
    if str=='-': return 0
def fun(str):
    operand = []
    operator = ['*','/','+','-']
    expr_operator = []
    for start in range(len(str)):
        if str[start].isnumeric():
            operand.append(str[start])
        elif str[start] in operator:
            expr_operator.append(str[start])

    print(operand,expr_operator)

def isNumb():


def isOperand():



def fun2(str):
    stack = []
    result = []
    for i in range(len(str)-1):
        if str[i] =='(':

        if str[i] == ')':
            while stack.pop != '(':
                stack.pop()

    print(result)

str = '3+(2(4+8))/6'
fun2(str)
# Out:
# ['(2(4']

# %%
# Write a program to count frequency of word in sentense

str = "rahul is rahul good boi but rahul rahul is good "

def fun(str):
    list1 = []
    word = ""
    for words in str:
        if words == " ":
            list1.append(word)
            word = ""
        else:
            word +=words
    list1.append(word)
    print(list1)
    result = dict()

    for word in list1:
        if word in result:
            result[word]+=1
        else:
            result[word]=1
    print(result)



fun(str)
# Out:
# ['rahul', 'is', 'rahul', 'good', 'boi', 'but', 'rahul', 'rahul', 'is', 'good', '']
# {'rahul': 4, 'is': 2, 'good': 2, 'boi': 1, 'but': 1, '': 1}

# %%
result = dict()
str = 'rahul is good boi but boi is kunal and rahul'
def fun(str):
    for i in str:
        if i==' ':
            continue
        else:
            if i in result:
                result[i] +=1
            else:
                result[i] = 1
fun(str)
print(result)
# Out:
# {'r': 2, 'a': 4, 'h': 2, 'u': 4, 'l': 3, 'i': 4, 's': 2, 'g': 1, 'o': 4, 'd': 2, 'b': 3, 't': 1, 'k': 1, 'n': 2}

# %%
# write a program to check weather first number is any power of 2nd number

def fun(num1,num2):
    n=1
    while (n<=num2):
        if num1 == num2**n:
            return n
        n+=1
print(fun(64,8))

def fun2(num1,num2):
# Out:
# 2

# %%
# calculate nth power suing recusrion
def fun8(num,pow):
    if pow == 0:
        return 0
    if pow==1:
        return num

    return num*fun(num,pow-1)

fun8(12,2)

# %%
def CountOnes(n):
    result = 0
    while(n>0):
        n = n & (n-1)
        result+=1
    return result

CountOnes(5)
# Out:
# 2

# %%
# write a program to implement stack in python push and pop

class Stack:

    def __init__(self,size):
        self.top = -1
        self.stack = [None]*size
        self.size = size
        print(self.stack)

    def push(self, item):
        if self.top == self.size:
            print("Stack is FUll")
        else:
            self.top += 1
            self.stack[self.top] = item

    def pop(self):
        if len(self.stack)!=0:
            temp = self.top
            self.top-=1
            return self.stack[temp]
        else:
            print("cant't delete stack is empty")
            return 0

    def showStack(self):
        temp = self.top
        while temp!=-1:
            print(self.stack[temp])
            temp-=1

stack = Stack(10)
stack.push(10)
stack.push(9)
stack.push(8)
stack.push(7)
stack.showStack()
stack.pop()
stack.showStack()
# Out:
# [None, None, None, None, None, None, None, None, None, None]
# 7
# 8
# 9
# 10
# 8
# 9
# 10

# %%
# Create linkedlist in python

class Node:
    def __init__(self,data):
        self.data = data
        self.next = None


class linkedlist:
    def __init__(self):
        self.head = None

    def insertAtBegin(self,data):
        new_node = Node(data)
        if self.head == None:
            self.head = new_node
            return
        new_node.next = self.head
        self.head = new_node

    def insertAtEnd(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return

        current_node = self.head
        while(current_node.next):
            current_node = current_node.next

        current_node.next = new_node

    def removeFristNode(self):
        if self.head == None:
            return
        self.head = self.head.next

    def removeLastNode(self):
        if self.head == None:
            return
        current_node = self.head
        while current_node.next != None and current_node.next.next != None:
            current_node = current_node.next

        current_node.next = None

    def printAll(self):
        current_node = self.head
        while current_node:
            print(current_node.data, end="->")
            current_node = current_node.next
        print()

    def removeNode(self, data, index):
        if index == 0:
            self.insertAtBegin(data)

        position = 0
        current_node = self.head
        while current_node != None and position +1 != index:
            position += 1
            current_node = current_node.next

        if current_node != None:
            new_node = Node(data)
            new_node.next = current_node.next
            current_node.next = new_node
        else:
            print("Index is not present...")


    def updateNode(self, data, index):
        current_node = self.head
        position = 0
        if index == position :
            current_node.data = data 

        else:
            while current_node != None and position+1 != index:
                position += 1
                current_node = current_node.next

            if current_node != None:
                current_node.data = data

            else:
                print("Index Dose not exist") 



link = linkedlist()

link.insertAtBegin(10)
link.insertAtEnd(20)
link.insertAtEnd(30)
link.insertAtEnd(40)
link.printAll()
link.updateNode(25,2)
link.printAll()
link.removeFristNode()
link.printAll()
link.removeLastNode()
link.printAll()
# Out:
# 10->20->30->40->
# 10->25->30->40->
# 25->30->40->
# 25->30->

# %%
class Queue:

    def __init__(self,size):
        self.front = -1
        self.rear  = -1
        self.queue = [None] * size
        self.size  = size
        print(self.queue)

    def pushRear(self,data):
        if self.rear == self.size:
            return "Can't insert More Queue is full"
        else:
            if self.front == -1:
                self.front+=1
            self.rear += 1
            self.queue[self.rear] = data

    def pushFront(self,data):
        if self.front == self.rear:
            return "can't insert the valuel"
            self.front+=1
            self.front += 1
            self.queue[self.front] = data

        temp = self.rear
        self.rear += 1
        while temp != 0:
            self.queue[temp+1]=self.queue[temp]
            temp -= 1
        self.queue[temp] = data

    def popFront(self):
        if self.front == -1 or self.rear == -1:
            return "Can't Delete Queue is Already empty"


    def showFornt(self):
        print(self.front)

    def showRear(self):
        print(self.rear)

    def showQueue(self):
        rear = self.rear
        front = self.front

        for item in range(front,rear+1):
            print(self.queue[item],end=" | ")

queue = Queue(10)


queue.pushRear("10")
queue.pushRear("20")
queue.pushRear("30")
queue.pushRear("40")
queue.showFornt()
queue.showRear()
queue.showQueue()
queue.pushFront(5)
print()
queue.showQueue()
queue.showRear()

queue.showFornt()
# Out:
# [None, None, None, None, None, None, None, None, None, None]
# 0
# 3
# 10 | 20 | 30 | 40 |
# 10 | 20 | 30 | 5 | None | 4
# 0

# %%
# write a program to find the product of consicative (which means difference numbers is 1) numbers in a list is x
def fun(list1,product):
    for i in range(len(list1)):
        for j in range(i+1,len(list1)):
            if list1[j] - list1[i] == 1 and list1[i] * list1[j] == product:
                    return (list1[i],list1[j])

list1 = [-4,5,6,-2,7,8,120,12,23,45,9]
fun(list1,72)
# Out:
# (8, 9)

# %% [markdown]
# #### Dynamic Programing:
# * similar to devide and conquer approch dynamic programming also combines the solution to sub problem it mainly used where soloution of subproblem is needed repetadly the computed solutions are stored into table, so that we don't have to recompute i.e overlapping sub problem exist
#
# * Examples: Floyd-Warshall and Bellman-Ford are typicall exmples of DP
#
# Steps of Dp:
# * Characterize the structure of Optimal soloution (Sorted Manner)
# * Recursively define the value of optimal soloution
# * compute values into recursive manner (bottom up approch)
# * Construct an optimal soloution form the computed information
#
# Devide and Conquer : problem devided into Disjoint set of sub problems solved recursively and then combined them to solve orignal problem
#
# DP: it used when sub problem are interdependant [over lapping of subproblems can happen] (sometimes they share same sub problem) in short problem is solved once and store into table
#
# Element of Dynamic Programming
# * substructure : devide problem into subproblem
# * table structure : store the result into table
# * bottom up approch : start form bottom
#
# Advantages of Dynamic Programming (DP):
# * Avoids recomputing the same subproblems multiple times, leading to significant time savings.
# * Ensures that the optimal solution is found by considering all possible combinations.
# * Breaks down complex problems into smaller, more manageable subproblems.
#
# Applications of DP:
# * Shortest path
# * Longest common Subsequence
# * Maximize CPU Cycles (no cycle get wested)

# %% [markdown]
# ##### Knapsack Problem
# * weight = maximum capacity of bag (Keep it minimum) W<=Capacity
# * value = price of item (keep it maximun)

# %%
def fun(n):
    if n<=1:
        return 1;

    if n%2==0:
        return fun(n/2)

    return fun(n/2) + fun(n/2+1)

print(fun(11))
# Out:
# 13930

# %%
# swap two numbers using numberrs

def fun(a,b):
    a = a^b
    b = b^a
    a = a^b

    return a,b

fun(10,15)
# Out:
# (15, 10)

# %%
# find smallest value from binary tree rep uisng dict
